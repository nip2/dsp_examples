# %%
from IPython.core.display import HTML 
HTML("<script>MathJax.Hub.Config({displayAlign: 'left'});</script>")

import numpy as np
from scipy import signal 
import matplotlib.pyplot as plt

# %%
wp = np.array([0.30,0.50]) # Where 1.0 = pi radians/sample 
ws = np.array([0.25,0.55]) # Where 1.0 = pi radians/sample

ap = 0.95

Rs = 60 # Stopband attenuation maximum
Rp = -20.0*np.log10(ap) # Maximum ripple in the passband. (dB)

def PlotSystem(sos):
    w, h = signal.sosfreqz(sos,2000)
    
    (zeros,poles,k) = signal.sos2zpk(sos)
    
    #fig = plt.figure()
    figure = plt.figure(num=1,figsize=(10,6),dpi=100) 
    figure.clf()
    axes = figure.add_subplot(3,2,1)
    for zeroAngle in np.angle(zeros):
        axes.axvline(zeroAngle,color='b',linestyle=':',linewidth=0.5)
    axes.plot(w, 20 * np.log10(np.maximum(abs(h), 1e-5)),color='r')
    yMin = -Rs-20
    yMax = 5.0
    axes.fill_between([0,ws[0]*np.pi],[-Rs,-Rs],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between([ws[1]*np.pi,np.pi],[-Rs,-Rs],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between(wp*np.pi,[yMin,yMin],[ap,ap],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between(wp*np.pi,[1.0,1.0],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.set_ylabel('Amplitude (dB)') 
    axes.set_ylim([yMin,yMax]) 
    axes.set_xlim([0.0,np.pi])
    
    axes = figure.add_subplot(3,2,2)
    axes.plot(w,abs(h),color='r')
    yMin = 0.0
    yMax = 1.05
    axes.fill_between([0,ws[0]*np.pi],[-Rs,-Rs],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between([ws[1]*np.pi,np.pi],[-Rs,-Rs],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between(wp*np.pi,[yMin,yMin],[ap,ap],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.fill_between(wp*np.pi,[1.0,1.0],[yMax,yMax],linewidth=0.0,facecolor='k',alpha=0.2) 
    axes.set_ylabel('Amplitude') 
    axes.set_ylim([0.0,1.05]) 
    axes.set_xlim([0.0,np.pi])
    
    axes = figure.add_subplot(3,2,3)
    for angle in np.arange(-360.0,360.0+1,180.0):
        axes.axhline(angle,color='k',linestyle=':',linewidth=0.5) 
    for zeroAngle in np.angle(zeros):
        axes.axvline(zeroAngle,color='b',linestyle=':',linewidth=0.5)
    axes.plot(w, np.angle(h)*(180.0/np.pi),color='g')
    axes.set_ylabel('Phase ($^o$)')
    axes.set_ylim([-190.0,190.0])
    axes.set_xlim([0.0,np.pi])

    axes = figure.add_subplot(3,2,4)
    phaseUnwrapped = np.unwrap(np.angle(h))*(180.0/np.pi) 
    for angle in np.arange(-360.0*10,360.0*10+1,180.0):
        axes.axhline(angle,color='k',linestyle=':',linewidth=0.5) 
    for zeroAngle in np.angle(zeros):
        axes.axvline(zeroAngle,color='b',linestyle=':',linewidth=0.5)
    axes.plot(w,phaseUnwrapped,color='g')
    axes.set_ylabel('Phase ($^o$)')
    axes.set_xlim([0.0,np.pi])
    axes.set_ylim(phaseUnwrapped.min(),phaseUnwrapped.max())
   
    (num,den) = signal.sos2tf(sos)
    wgd,groupDelay = signal.group_delay((num,den), w=2**12) 
    groupDelay[0] = 0.0
    axes = figure.add_subplot(3,2,5)
    for zeroAngle in np.angle(zeros):
        axes.axvline(zeroAngle,color='b',linestyle=':',linewidth=0.5)
    axes.axhline(0.0,color='k',linestyle=':',linewidth=0.5)
    axes.plot(wgd, groupDelay)
    axes.set_ylabel('GD ($n$)')
    axes.set_ylim(np.percentile(groupDelay,[0.05,99.5]))
    axes.set_xlim([0.0,np.pi])
    
    axes = figure.add_subplot(3,2,6)
    (num,den) = signal.sos2tf(sos)
    ni = np.arange(150)
    xi = signal.unit_impulse(ni.shape)
    hi = signal.lfilter(num,den,xi)
    axes.axhline(0.0,color='k',linestyle=':',linewidth=0.5)
    axes.vlines(ni,0,hi,color='b')
    axes.set_ylabel('h[n]')
    axes.set_xlim([0.0,ni[-1]+0.5])
   
    figure = plt.figure(num=2,figsize=(4,4),dpi=100)
    figure.clf()
    
    axes = figure.add_subplot(1,1,1)
    t = np.linspace(0,np.pi*2,100)
    axes.plot(np.cos(t), np.sin(t),color='k',linewidth=0.8,linestyle=':')
    axes.axhline(0.0,color='k',linewidth=0.8,linestyle=':')
    axes.axvline(0.0,color='k',linewidth=0.8,linestyle=':')
    axes.plot(np.real(zeros),np.imag(zeros),marker='o',linestyle='none',markerfacecolor='None',color='b',linewidth=0.1)
    axes.plot(np.real(poles),np.imag(poles),marker='x',linestyle='none',color='r',linewidth=0.1)
    axes.set_xlim([-1.2,1.2])
    axes.set_ylim([-1.2,1.2])
    axes.set_aspect('equal')
    axes.set_xlabel('Real')
    axes.set_ylabel('Imaginary')
    axes.axis('off')

# %%
(ord,wn) = signal.ellipord(wp, ws, Rp, Rs)
sos = signal.iirfilter(ord,wn,rp=Rp,rs=Rs,btype='band',ftype='ellip',output='sos') 
PlotSystem(sos)

# %%
(ord,wn) = signal.buttord(wp, ws, Rp, Rs)
sos = signal.iirfilter(ord,wn,rp=Rp,rs=Rs,btype='band',ftype='butter',output='sos') 
PlotSystem(sos)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/signal/filter_design.py:689: UserWarning: The group delay is singular at frequencies [0.000, 0.001, 0.002, 0.002, 0.003, 0.004, 0.005, 0.005, 0.006, 0.007, 0.008, 0.008, 0.009, 0.010, 0.011, 0.012, 0.012, 0.013, 0.014, 0.015, 0.015, 0.016, 0.017, 0.018, 0.018, 0.019, 0.020, 0.021, 0.021, 0.022, 0.023, 0.024, 0.025, 0.025, 0.026, 0.027, 0.028, 0.028, 0.029, 0.030, 0.031, 0.031, 0.032, 0.033, 0.034, 0.035, 0.035, 0.036, 0.037, 0.038, 0.038, 0.039, 0.040, 0.041, 0.041, 0.042, 0.043, 0.044, 0.044, 0.045, 0.046, 0.047, 0.048, 0.048, 0.049, 0.050, 0.051, 0.051, 0.052, 0.053, 0.054, 0.054, 0.055, 0.056, 0.057, 0.058, 0.058, 0.059, 0.060, 0.061, 0.061, 0.062, 0.063, 0.064, 0.064, 0.065, 0.066, 0.067, 0.067, 0.068, 0.069, 0.070, 0.071, 0.071, 0.072, 0.073, 0.074, 0.074, 0.075, 0.076, 0.077, 0.077, 0.078, 0.079, 0.080, 0.081, 0.081, 0.082, 0.083, 0.084, 0.084, 0.085, 0.086, 0.087, 0.087, 0.088, 0.089, 0.090, 0.091, 0.091, 0.092, 0.093, 0.094
, 0.338, 0.339, 0.340, 0.341, 0.341, 3.052, 3.053, 3.053, 3.054, 3.055, 3.056, 3.056, 3.057, 3.058, 3.059, 3.060, 3.060, 3.061, 3.062, 3.063, 3.063, 3.064, 3.065, 3.066, 3.066, 3.067, 3.068, 3.069, 3.069, 3.070, 3.071, 3.072, 3.073, 3.073, 3.074, 3.075, 3.076, 3.076, 3.077, 3.078, 3.079, 3.079, 3.080, 3.081, 3.082, 3.083, 3.083, 3.084, 3.085, 3.086, 3.086, 3.087, 3.088, 3.089, 3.089, 3.090, 3.091, 3.092, 3.093, 3.093, 3.094, 3.095, 3.096, 3.096, 3.097, 3.098, 3.099, 3.099, 3.100, 3.101, 3.102, 3.102, 3.103, 3.104, 3.105, 3.106, 3.106, 3.107, 3.108, 3.109, 3.109, 3.110, 3.111, 3.112, 3.112, 3.113, 3.114, 3.115, 3.116, 3.116, 3.117, 3.118, 3.119, 3.119, 3.120, 3.121, 3.122, 3.122, 3.123, 3.124, 3.125, 3.125, 3.126, 3.127, 3.128, 3.129, 3.129, 3.130, 3.131, 3.132, 3.132, 3.133 ...
#   format(", ".join("{0:.3f}".format(ws) for ws in w[singular]))

# %%
(ord,wn) = signal.cheb1ord(wp, ws, Rp, Rs)
sos = signal.iirfilter(ord,wn,rp=Rp,rs=Rs,btype='band',ftype='cheby1',output='sos') 
PlotSystem(sos)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/signal/filter_design.py:689: UserWarning: The group delay is singular at frequencies [0.000, 0.001, 0.002, 0.002, 0.003, 0.004, 0.005, 0.005, 0.006, 0.007, 0.008, 0.008, 0.009, 0.010, 0.011, 0.012, 0.012, 0.013, 0.014, 0.015, 0.015, 0.016, 0.017, 0.018, 0.018, 0.019, 0.020, 0.021, 0.021, 0.022, 0.023, 0.024, 0.025, 0.025, 0.026, 0.027, 0.028, 0.028, 0.029, 0.030, 0.031, 0.031, 0.032, 0.033, 0.034, 0.035, 0.035, 0.036, 0.037, 0.038, 0.038, 0.039, 0.040, 0.041, 0.041, 0.042, 0.043, 0.044, 0.044, 0.045, 0.046, 0.047, 0.048, 0.048, 0.049, 0.050, 0.051, 0.051, 0.052, 0.053, 0.054, 0.054, 0.055, 0.056, 0.057, 0.058, 0.058, 0.059, 0.060, 0.061, 0.061, 0.062, 0.063, 0.064, 0.064, 0.065, 0.066, 0.067, 0.067, 0.068, 0.069, 0.070, 0.071, 0.071, 0.072, 0.073, 3.105, 3.106, 3.106, 3.107, 3.108, 3.109, 3.109, 3.110, 3.111, 3.112, 3.112, 3.113, 3.114, 3.115, 3.116, 3.116, 3.117, 3.118, 3.119, 3.119, 3.120, 3.121, 3.122, 3.122, 3.123, 3.124, 3.125, 3.125, 3.126, 3.127, 3.128, 3.129, 3.129, 3.130, 3.131, 3.132, 3.132, 3.133, 3.134, 3.135, 3.135, 3.136, 3.137, 3.138, 3.139, 3.139, 3.140, 3.141], setting to 0
#   format(", ".join("{0:.3f}".format(ws) for ws in w[singular]))

# %%
(ord,wn) = signal.cheb2ord(wp, ws, Rp, Rs)
sos = signal.iirfilter(ord,wn,rp=Rp,rs=Rs,btype='band',ftype='cheby2',output='sos') 
PlotSystem(sos)
